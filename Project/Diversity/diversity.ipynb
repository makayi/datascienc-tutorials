# %%
import  numpy as np
import pandas as pd
import  matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
# %matplotlib inline

df= pd.read_csv('diversity_data.csv')
df
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>company</th>
#       <th>year</th>
#       <th>race</th>
#       <th>gender</th>
#       <th>job_category</th>
#       <th>count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>23andMe</td>
#       <td>2016</td>
#       <td>Latino</td>
#       <td>male</td>
#       <td>Executive/Senior officials &amp; Mgrs</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>23andMe</td>
#       <td>2016</td>
#       <td>Latino</td>
#       <td>male</td>
#       <td>First/Mid officials &amp; Mgrs</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>2</th>
# ...

# %%
female=df[df['gender']=='female']
female.groupby('company')
female.count()
# Out:
# company         1848
# year            1848
# race            1848
# gender          1848
# job_category    1848
# count           1848
# dtype: int64

# %%
df['race'].value_counts()
# Out:
# Latino                                 528
# Black_or_African_American              528
# Asian                                  528
# American_Indian_Alaskan_Native         528
# Native_Hawaiian_or_Pacific_Islander    528
# Two_or_more_races                      528
# White                                  528
# Overall_totals                         264
# Name: race, dtype: int64

# %%
df[df['gender']=='female']['gender'].count()
# Out:
# 1848

# %%
df[df['gender']=='male']['gender'].count()
# Out:
# 1848

# %%
df['job_category'].nunique()
# Out:
# 12

# %%
df.columns
# Out:
# Index(['company', 'year', 'race', 'gender', 'job_category', 'count'], dtype='object')

# %%
df[df['race']=='Latino'].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 528 entries, 0 to 3803
# Data columns (total 6 columns):
# company         528 non-null object
# year            528 non-null int64
# race            528 non-null object
# gender          528 non-null object
# job_category    528 non-null object
# count           528 non-null object
# dtypes: int64(1), object(5)
# memory usage: 28.9+ KB

# %%
df[df['race']=='White'].count()
# Out:
# company         528
# year            528
# race            528
# gender          528
# job_category    528
# count           528
# dtype: int64

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# TypeError: an integer is required
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-132-6bae101f211f> in <module>()
# ----> 1 r=df[df['race']=='Black'].count()
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/series.py in __getitem__(self, key)
#     621         key = com._apply_if_callable(key, self)
#     622         try:
# --> 623             result = self.index.get_value(self, key)
#     624
#     625             if not is_scalar(result):
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/indexes/base.py in get_value(self, series, key)
# ...

# %%
groups=df[(df['race']=='White')&(df['gender']=='female') ].groupby('job_category')
groups=groups.nunique()
groups[['job_category','count']].sort_values(by='count')
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>job_category</th>
#       <th>count</th>
#     </tr>
#     <tr>
#       <th>job_category</th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Craft workers</th>
#       <td>1</td>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>laborers and helpers</th>
#       <td>1</td>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>operatives</th>
#       <td>1</td>
#       <td>5</td>
#     </tr>
#     <tr>
#       <th>Service workers</th>
#       <td>1</td>
#       <td>6</td>
#     </tr>
#     <tr>
#       <th>Technicians</th>
#       <td>1</td>
#       <td>10</td>
# ...

# %%
# Out:
# 1    12
# Name: race, dtype: int64

# %%
groups=df[(df['race']=='Latino')&(df['gender']=='female') ].groupby('job_category')
groups=groups.nunique()
groups[['job_category','count']].sort_values(by='count')
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>job_category</th>
#       <th>count</th>
#     </tr>
#     <tr>
#       <th>job_category</th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Craft workers</th>
#       <td>1</td>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>laborers and helpers</th>
#       <td>1</td>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>operatives</th>
#       <td>1</td>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>Service workers</th>
#       <td>1</td>
#       <td>6</td>
#     </tr>
#     <tr>
#       <th>Executive/Senior officials &amp; Mgrs</th>
# ...

# %%
groups=df[(df['race']=='Latino')&(df['gender']=='female') ].groupby('job_category')
groups=groups.nunique()
groups[['job_category','count']].sort_values(by='count')
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>job_category</th>
#       <th>count</th>
#     </tr>
#     <tr>
#       <th>job_category</th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Craft workers</th>
#       <td>1</td>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>laborers and helpers</th>
#       <td>1</td>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>operatives</th>
#       <td>1</td>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>Service workers</th>
#       <td>1</td>
#       <td>6</td>
#     </tr>
#     <tr>
#       <th>Executive/Senior officials &amp; Mgrs</th>
# ...

# %%
groups=df[(df['race']=='White')&(df['gender']=='female') &(df['job_category']=='operatives') ]
groups.count()
# Out:
# company         22
# year            22
# race            22
# gender          22
# job_category    22
# count           22
# dtype: int64

# %%
groups=df[(df['race']=='Latino')&(df['gender']=='female') &(df['job_category']=='operatives') ]
groups.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 22 entries, 19 to 3799
# Data columns (total 6 columns):
# company         22 non-null object
# year            22 non-null int64
# race            22 non-null object
# gender          22 non-null object
# job_category    22 non-null object
# count           22 non-null object
# dtypes: int64(1), object(5)
# memory usage: 1.2+ KB

# %%
races=df['race'].unique()
count=df['race'].value_counts(normalize=False)
count=np.array(count)

sns.barplot(x=races,y=count)

# %%
gendergroup=df.groupby('gender')

gendergroup.count()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>company</th>
#       <th>year</th>
#       <th>race</th>
#       <th>job_category</th>
#       <th>count</th>
#     </tr>
#     <tr>
#       <th>gender</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>female</th>
#       <td>1848</td>
#       <td>1848</td>
#       <td>1848</td>
#       <td>1848</td>
#       <td>1848</td>
#     </tr>
#     <tr>
#       <th>male</th>
#       <td>1848</td>
#       <td>1848</td>
#       <td>1848</td>
#       <td>1848</td>
#       <td>1848</td>
#     </tr>
#   </tbody>
# </table>
# ...

# %%
df
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
# 5       False
# 6       False
# 7       False
# 8       False
# 9       False
# 10      False
# 11      False
# 12       True
# 13       True
# 14       True
# 15       True
# 16       True
# 17       True
# 18       True
# 19       True
# 20       True
# 21       True
# 22       True
# 23       True
# 24      False
# 25      False
# 26      False
# 27      False
# 28      False
# 29      False
#         ...
# 3930     True
# 3931     True
# 3932     True
# 3933     True
# 3934     True
# 3935     True
# 3936     True
# 3937     True
# 3938     True
# 3939     True
# 3940     True
# 3941     True
# 3942     True
# 3943     True
# 3944     True
# 3945     True
# 3946     True
# 3947     True
# 3948    False
# 3949    False
# 3950    False
# 3951    False
# 3952    False
# 3953    False
# 3954    False
# 3955    False
# 3956    False
# 3957    False
# 3958    False
# 3959    False
# ...
